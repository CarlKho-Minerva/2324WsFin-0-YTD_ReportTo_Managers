# %%
#install dependencies
# %pip install csv
# %pip install pandas
# %pip install schedule
# %pip install time
# %pip install datetime

# %%
import csv
import pandas as pd

# Read the CSV file into a DataFrame
sheet = pd.read_csv(
    "YTD and Spring semester total hours  - Total Hours Summa.csv")  # Replace with the path to your CSV file

# Create an empty dictionary to store messages for each manager
messages_dict = {}

# Group the DataFrame by "Manager Email"
grouped_sheet = sheet.groupby("Manager Email")

# Loop through each group
for email, group in grouped_sheet:
    # Get the manager's name and email address
    manager_name = group["Manager Name"].iloc[0]
    manager_email = email

    # Print a message to confirm the manager's name and email address
    print(f"Creating message for {manager_name} at {manager_email}...")

    # Loop through each intern in the group
    message = f"Dear {manager_name},\n\nI hope you are doing well.\n\n\nBelow, you can find the Year-to-Date and Semester total hours of your WS interns.\n\n"

    for index, row in group.iterrows():
        student_first_name = row["Student First Name"]
        student_last_name = row["Student Last Name"]
        ytd = row["Year-To-Date Total Hours"]
        spring = row["Spring Total Hours"]
        left_hours = row["Total Spring hours left"]
        message += f"{student_first_name} {student_last_name}: YTD = {ytd}, Spring hours = {spring}, Hours left to work = {left_hours}\n\n"

    message += "Best,\nStudent Finance Team"

    # Add the message to the messages_dict, with the manager's email as the key
    messages_dict[manager_email] = message

# Write the messages to a CSV file
with open("messages.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Manager Email", "Message"])
    for email, message in messages_dict.items():
        writer.writerow([email, message])

print("CSV file created successfully.")
# Out:
# Creating message for  Aboozar Hadavand at AHadavand@minerva.edu...
# Creating message for  John Cote at JCote@minerva.edu...
# Creating message for  Jon Wilkins at JWilkins@minerva.edu...
# Creating message for  Lindsey Fiorelli at LFiorelli@minerva.edu...
# Creating message for  Will Meek at WMeek@minerva.edu...
# Creating message for  Alexis Diamond at adiamond@minerva.edu...
# Creating message for  Ali Digby at adigby@minerva.edu...
# Creating message for  Andy Dosmann at adosmann@minerva.edu...
# Creating message for  Allie Gale at agale@minerva.edu...
# Creating message for  Alena Savitskaya at alena@minerva.edu...
# Creating message for  Amber Featherstone at amberfeatherstone@minerva.edu...
# Creating message for  Angelina Pilacelli at angelina@minerva.edu...
# Creating message for   Alexandra Terrana at aterrana@minerva.edu...
# Creating message for  Aysenur Sagdic at aysenursagdic@minervaproject.com...
# Creating message for  Ben Wilkoff at ben.wilkoff@minerva.edu...
# Creating message for  Ben Nelson at ben@minerva.edu...
# Creating message for  Branden Balenzuela at branden@minerva.edu...
# Creating message for  Benoit Richard at brichard@minerva.edu...
# Creating message for  Aaron Lawry at calawry@minerva.edu...
# Creating message for  Catie Carter at cmcarter@minerva.edu...
# Creating message for  Cheryl Moy at cmoy@minerva.edu...
# Creating message for  Cristi Dragan at cristi@minerva.edu...
# Creating message for  Daniel Curme at dan@minerva.edu...
# Creating message for  David Levi at david@minerva.edu...
# Creating message for  Diana Goldemberg at dgoldemberg@minerva.edu...
# Creating message for  Diana ElAzar at diana.elazar@minervaproject.com...
# Creating message for  Torsten Doering at doering@minerva.edu...
# Creating message for  Engin Volkan at evolkan@minerva.edu...
# Creating message for  Fangyun Hsu at fangyun@minerva.edu...
# Creating message for  Fatou  Badiane-Toure at fatou@minerva.edu...
# Creating message for  Florin-Stefan Morar at fmorar@minerva.edu...
# Creating message for  Geneva Stein at gstein@minerva.edu...
# Creating message for  Grace WoodsPuckett at gwoodspuckett@minerva.edu...
# Creating message for  John Levitt at jlevitt@minerva.edu...
# Creating message for  Jonathan Powers at jpowers@minerva.edu...
# Creating message for  Kayla Krupnick Walsh at kaylakw@minerva.edu...
# Creating message for  Katie Donnelly at kdonnelly@minerva.edu...
# Creating message for  Kenn Ross at kenn@minerva.edu...
# Creating message for  Katie McAllister at kmcallister@minerva.edu...
# Creating message for  Lucas Tambasco at ltambasco@minerva.edu...
# Creating message for  Manu  Jayamohan  at manu@minerva.edu ...
# Creating message for  Michael Bogucki at mbogucki@minerva.edu...
# Creating message for  Megan Christensen at megan@minerva.edu...
# Creating message for  Matthew Erskine at merskine@minerva.edu...
# Creating message for  Mark Kukis at mkukis@minerva.edu...
# Creating message for  Melissa Morgenstern at mmorgenstern@minerva.edu...
# Creating message for  Marianna Panossi at mpanossi@minerva.edu...
# Creating message for  Mark Sheskin at msheskin@minerva.edu...
# Creating message for  Melissa Yates at myates@minerva.edu...
# Creating message for  NIKOLAUS PELKA at niko@minerva.edu...
# Creating message for  Nick Kenney at nkenney@minerva.edu...
# Creating message for  Nikhil Mathur at nmathur@minerva.edu...
# Creating message for  Perpetua Nganga at pnganga@minerva.edu...
# Creating message for  Patrick Watson at pwatson@minerva.edu...
# Creating message for  Peter Zoogman at pzoogman@minerva.edu...
# Creating message for  Randi Doyle at rdoyle@minerva.edu...
# Creating message for  Raquel Ribeiro at ribeiro@minerva.edu...
# Creating message for  Rob Karl at rkarl@minerva.edu...
# Creating message for  Rena Levitt at rlevitt@minerva.edu...
# Creating message for  Robson Morgan at rmorgan@minerva.edu...
# Creating message for  Rohan Shekhar at rshekhar@minerva.edu...
# Creating message for  Carl Scheffler at scheffler@minerva.edu...
# Creating message for  Shona Kinzel at shona@minerva.edu...
# Creating message for  Suzanne Kern at skern@minerva.edu...
# Creating message for  Sultanna Krispil at sultanna@minerva.edu...
# Creating message for  TINA LO at tina@minerva.edu...
# Creating message for  TJ Kimball at tj@minerva.edu...
# Creating message for  Tomer Perry at tperry@minerva.edu...
# Creating message for  Travis Deuerling at travis@minerva.edu...
# Creating message for  Ty Robbins at trobbins@minerva.edu...
# Creating message for  Trisha Stan at tstan@minerva.edu...
# Creating message for  Jess Varghese at varghese@minerva.edu...
# Creating message for  veselina Nedelcheva at veselina@minerva.edu...
# Creating message for  Vivian Zhao at vzhao@minerva.edu...
# CSV file created successfully.
